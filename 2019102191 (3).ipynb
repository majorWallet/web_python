# %%
file = open('QA.txt', 'r')
old_fileMatrix = file.readlines()
fileMatrix = []
wordMatrix = []
for i in range(len(old_fileMatrix)):
    fileMatrix.append(old_fileMatrix[i].strip(".").strip("!").strip(",").strip("?").strip('Q :').strip('A :').strip('title :'))
for i in range(len(fileMatrix)):
    print(fileMatrix[i])
# Out:
# Abner Doubleday
#
#
#
# When did Abner Doubleday have a relationship with baseball?
#
#
#
# he is more widely known as the supposed inventor of the game of baseball, in Elihu Phinney's cow pasture in Cooperstown, New York, in 1839.
#
# How did he invent baseball?
#
# he is more widely known as the supposed inventor of the game of baseball,
#
# When did he invent baseball?
#
# 1839.
#
# Who played baseball after Doubleday invented it?
#
# cannot answer
#
# Why is baseball interesting with Doubleday?
#
# There may have been some relationship to baseball as a national sport and Abner Doubleday.
#
# What happened after he invented baseball?
#
# braham G. Mills, the fourth president of the National League, was appointed in 1905 to determine the origin of baseball.
#
# What did Mills say about Doubleday?
#
# he first scheme for playing baseball, according to the best evidence obtainable to date, was devised by Abner Doubleday at Cooperstown, New York, in 1839."
#
# ...
